# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv("C:\Users\kband\OneDrive\Documents\IPL_5.csv")
# Out:
#   Cell In[7], line 1
#     data=pd.read_csv("C:\Users\kband\OneDrive\Documents\IPL_5.csv")
#                                                                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data = pd.read_csv("C:\\Users\\kband\\OneDrive\\Documents\\IPL_5.csv")

# %%
data
# Out:
#        Unnamed: 0  mid        date                                      venue  \
# 0               0    1  2008-04-18                      M Chinnaswamy Stadium
# 1               1    1  2008-04-18                      M Chinnaswamy Stadium
# 2               2    1  2008-04-18                      M Chinnaswamy Stadium
# 3               3    1  2008-04-18                      M Chinnaswamy Stadium
# 4               4    1  2008-04-18                      M Chinnaswamy Stadium
# ...           ...  ...         ...                                        ...
# 76009       76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010       76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011       76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012       76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013       76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
# ...
